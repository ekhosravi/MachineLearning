# %% [markdown]
# # <img src="https://filoger.com/wp-content/uploads/2021/09/circle-logo-1536x1536.png" alt="keras" width="150" height="150">
# <h1 align=center><font size = 7>Lab 03 : Pandas</font></h1>
# <h1 align=center><font size = 4>Hands-On Machine Learning, 1401 | DeadLine: 19th Mehr, 13:00 </font></h1>

# %% [markdown]
# ## Table of Exercises!
#
# 1. [Question 01](#question01)
# 2. [Question 02](#question02).
# 3. [Question 03](#question03).
# 4. [Question 04](#question04).
# 5. [Question 05](#question05).
# 6. [Question 06](#question06).
# 7. [Question 07](#question07).
# 6. [Question 08](#question08).
# 6. [Question 09](#question09).

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # Read data

# %%
df = pd.read_csv("ds_salaries.csv")

# %% [markdown]
# <a id='question01'></a>
# ## Question 01

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0          77       2021               MI              PT
# 1         244       2021               EN              FT
# 2          52       2020               EN              FT
# 3         606       2022               MI              FT
# 4         391       2022               MI              FT
#
#                        job_title   salary salary_currency  salary_in_usd  \
# 0  3D Computer Vision Researcher   400000             INR           5409
# 1                   AI Scientist  1335000             INR          18053
# 2                   AI Scientist   300000             DKK          45896
# 3                   AI Scientist   200000             USD         200000
# 4                   AI Scientist   120000             USD         120000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 IN            50               IN            M
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 602         174       2021               SE              FT
# 603         203       2021               SE              FT
# 604         211       2021               MI              FT
# 605          26       2020               EN              FT
# 606         283       2021               SE              CT
#
#                 job_title  salary salary_currency  salary_in_usd  \
# 602    Research Scientist   51400             EUR          60757
# 603    Research Scientist   50000             USD          50000
# 604    Research Scientist   48000             EUR          56738
# 605    Research Scientist   42000             USD          42000
# 606  Staff Data Scientist  105000             USD         105000
#
#     employee_residence  remote_ratio company_location company_size
# 602                 PT            50               PT            L
# 603                 FR           100               US            S
# ...

# %% [markdown]
# <a id='question02'></a>
# ## Question 02

# %%
print("Rows Count : {}     And    Columns Count : {}".format(df.shape[0], df.shape[1]))
# Out:
# Rows Count : 607     And    Columns Count : 12

# %% [markdown]
# <a id='question03'></a>
# ## Question 03

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %% [markdown]
# <a id='question04'></a>
# ## Question 04

# %%
df_c = df.groupby(['job_title']).count()

# %%
df_c = df_c[[]]
df_c
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# <a id='question05'></a>
# ## Question 05

# %%
max_index = df['salary'].idxmax()

df.iloc[max_index]['job_title']
# Out:
# 'Data Scientist'

# %% [markdown]
# <a id='question06'></a>
# ## Question 06

# %%
df_new = df[['job_title' , 'salary']]  
df2 = df_new.groupby('job_title').mean().reset_index()

df2[df2['job_title'] == 'Machine Learning Engineer']
# Out:
#                     job_title         salary
# 38  Machine Learning Engineer  272717.878049

# %% [markdown]
# <a id='question07'></a>
# ## Question 07

# %%
df_new = df[['job_title' , 'work_year', 'experience_level' , 'salary', 'company_size']]

df2 = df_new.loc[df_new.groupby(["job_title"])["salary"].idxmin()]  

df2.sort_values(by='salary', ascending=True)[:10]
# Out:
#                       job_title  work_year experience_level  salary  \
# 303               Data Engineer       2021               MI    4000
# 473              Data Scientist       2021               EN    4000
# 148                Data Analyst       2020               MI    8000
# 26              BI Data Analyst       2021               EN    9272
# 48     Computer Vision Engineer       2022               EN   10000
# 6                  AI Scientist       2021               EN   12000
# 567  Machine Learning Scientist       2021               MI   12000
# 574                 ML Engineer       2020               EN   14000
# 35            Big Data Engineer       2021               MI   18000
# 555   Machine Learning Engineer       2021               EN   20000
#
#     company_size
# 303            M
# 473            M
# 148            L
# 26             S
# 48             M
# 6              S
# 567            M
# 574            S
# 35             S
# 555            S

# %% [markdown]
# <a id='question08'></a>
# ## Question 08
#
#
#
# <hr>
# Use groupby
#
# job_title, count

# %%
df.groupby('job_title').size()
# Out:
# job_title
# 3D Computer Vision Researcher                 1
# AI Scientist                                  7
# Analytics Engineer                            4
# Applied Data Scientist                        5
# Applied Machine Learning Scientist            4
# BI Data Analyst                               6
# Big Data Architect                            1
# Big Data Engineer                             8
# Business Data Analyst                         5
# Cloud Data Engineer                           2
# Computer Vision Engineer                      6
# Computer Vision Software Engineer             3
# Data Analyst                                 97
# Data Analytics Engineer                       4
# Data Analytics Lead                           1
# Data Analytics Manager                        7
# Data Architect                               11
# Data Engineer                               132
# Data Engineering Manager                      5
# ...

# %% [markdown]
# <a id='question09'></a>
# ## Question 09

# %%
df.groupby(['work_year']).apply(lambda grp: grp.nlargest(3, 'salary'))
# Out:
#                work_year experience_level employment_type  \
# work_year
# 2020      332       2020               MI              FT
#           172       2020               EN              FT
#           333       2020               MI              FT
# 2021      331       2021               MI              FT
#           21        2021               MI              FT
#           569       2021               MI              FT
# 2022      498       2022               EX              FT
#           335       2022               MI              FT
#           36        2022               MI              FT
#
#                               job_title    salary salary_currency  \
# work_year
# 2020      332            Data Scientist  11000000             HUF
#           172             Data Engineer   4450000             JPY
#           333            Data Scientist   3000000             INR
# 2021      331            Data Scientist  30400000             CLP
# ...

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h1 class="alert-heading">Well done!</h1>
#   <p>Best Wishes!, Filoger</p>
# </div>
