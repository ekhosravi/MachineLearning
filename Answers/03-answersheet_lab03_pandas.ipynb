# %% [markdown]
# # <img src="https://filoger.com/wp-content/uploads/2021/09/circle-logo-1536x1536.png" alt="keras" width="150" height="150">
# <h1 align=center><font size = 7>Lab 03 : Pandas</font></h1>
# <h1 align=center><font size = 4>Hands-On Machine Learning, 1401 | DeadLine: 19th Mehr, 13:00 </font></h1>

# %% [markdown]
# ## Table of Exercises!
#
# 1. [Question 01](#question01)
# 2. [Question 02](#question02).
# 3. [Question 03](#question03).
# 4. [Question 04](#question04).
# 5. [Question 05](#question05).
# 6. [Question 06](#question06).
# 7. [Question 07](#question07).
# 6. [Question 08](#question08).
# 6. [Question 09](#question09).

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Read data

# %%
df = pd.read_csv('ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# <a id='question01'></a>
# ## Question 01

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %% [markdown]
# <a id='question02'></a>
# ## Question 02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.shape
# Out:
# (607, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
n = 0
for column in df.columns:
    n += 1
    print(f'{n}. {column}')
# Out:
# 1. Unnamed: 0
# 2. work_year
# 3. experience_level
# 4. employment_type
# 5. job_title
# 6. salary
# 7. salary_currency
# 8. salary_in_usd
# 9. employee_residence
# 10. remote_ratio
# 11. company_location
# 12. company_size

# %% [markdown]
# **Basic information of this dataset:**

# %% [raw]
# Based on the obtained information, this dataset contains 607 subjects (rows) and 12 features (columns).
# Its type is DataFrame and its data type is string(object(7)) and integer(5).
# This dataset has no missing data.
#
# The features are:
# Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location and company_size.

# %%
df.isnull()
# Out:
#      work_year  experience_level  employment_type  job_title  salary  \
# 0        False             False            False      False   False
# 1        False             False            False      False   False
# 2        False             False            False      False   False
# 3        False             False            False      False   False
# 4        False             False            False      False   False
# ..         ...               ...              ...        ...     ...
# 602      False             False            False      False   False
# 603      False             False            False      False   False
# 604      False             False            False      False   False
# 605      False             False            False      False   False
# 606      False             False            False      False   False
#
#      salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# <a id='question03'></a>
# ## Question 03

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %% [markdown]
# <a id='question04'></a>
# ## Question 04

# %%
df['job_title'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
set(df['job_title'])
# Out:
# {'3D Computer Vision Researcher',
#  'AI Scientist',
#  'Analytics Engineer',
#  'Applied Data Scientist',
#  'Applied Machine Learning Scientist',
#  'BI Data Analyst',
#  'Big Data Architect',
#  'Big Data Engineer',
#  'Business Data Analyst',
#  'Cloud Data Engineer',
#  'Computer Vision Engineer',
#  'Computer Vision Software Engineer',
#  'Data Analyst',
#  'Data Analytics Engineer',
#  'Data Analytics Lead',
#  'Data Analytics Manager',
#  'Data Architect',
#  'Data Engineer',
#  'Data Engineering Manager',
#  'Data Science Consultant',
#  'Data Science Engineer',
#  'Data Science Manager',
#  'Data Scientist',
#  'Data Specialist',
#  'Director of Data Engineering',
#  'Director of Data Science',
#  'ETL Developer',
#  'Finance Data Analyst',
#  'Financial Data Analyst',
#  'Head of Data',
#  'Head of Data Science',
#  'Head of Machine Learning',
#  'Lead Data Analyst',
#  'Lead Data Engineer',
#  'Lead Data Scientist',
#  'Lead Machine Learning Engineer',
#  'ML Engineer',
# ...

# %%
n = 0
for job in df['job_title'].unique():
    n += 1
    print(f'{n}. {job}')
# Out:
# 1. Data Scientist
# 2. Machine Learning Scientist
# 3. Big Data Engineer
# 4. Product Data Analyst
# 5. Machine Learning Engineer
# 6. Data Analyst
# 7. Lead Data Scientist
# 8. Business Data Analyst
# 9. Lead Data Engineer
# 10. Lead Data Analyst
# 11. Data Engineer
# 12. Data Science Consultant
# 13. BI Data Analyst
# 14. Director of Data Science
# 15. Research Scientist
# 16. Machine Learning Manager
# 17. Data Engineering Manager
# 18. Machine Learning Infrastructure Engineer
# 19. ML Engineer
# 20. AI Scientist
# 21. Computer Vision Engineer
# 22. Principal Data Scientist
# 23. Data Science Manager
# 24. Head of Data
# 25. 3D Computer Vision Researcher
# 26. Data Analytics Engineer
# 27. Applied Data Scientist
# 28. Marketing Data Analyst
# 29. Cloud Data Engineer
# 30. Financial Data Analyst
# 31. Computer Vision Software Engineer
# 32. Director of Data Engineering
# 33. Data Science Engineer
# 34. Principal Data Engineer
# 35. Machine Learning Developer
# ...

# %%
pd.DataFrame(df['job_title'].unique())
# Out:
#                                            0
# 0                             Data Scientist
# 1                 Machine Learning Scientist
# 2                          Big Data Engineer
# 3                       Product Data Analyst
# 4                  Machine Learning Engineer
# 5                               Data Analyst
# 6                        Lead Data Scientist
# 7                      Business Data Analyst
# 8                         Lead Data Engineer
# 9                          Lead Data Analyst
# 10                             Data Engineer
# 11                   Data Science Consultant
# 12                           BI Data Analyst
# 13                  Director of Data Science
# 14                        Research Scientist
# 15                  Machine Learning Manager
# 16                  Data Engineering Manager
# 17  Machine Learning Infrastructure Engineer
# 18                               ML Engineer
# 19                              AI Scientist
# ...

# %%
df['job_title'].unique().shape[0]
# Out:
# 50

# %%
pd.DataFrame(df['job_title'].unique(), columns=['job_title'], 
             index=range(1, df['job_title'].unique().shape[0]+1))
# Out:
#                                    job_title
# 1                             Data Scientist
# 2                 Machine Learning Scientist
# 3                          Big Data Engineer
# 4                       Product Data Analyst
# 5                  Machine Learning Engineer
# 6                               Data Analyst
# 7                        Lead Data Scientist
# 8                      Business Data Analyst
# 9                         Lead Data Engineer
# 10                         Lead Data Analyst
# 11                             Data Engineer
# 12                   Data Science Consultant
# 13                           BI Data Analyst
# 14                  Director of Data Science
# 15                        Research Scientist
# 16                  Machine Learning Manager
# 17                  Data Engineering Manager
# 18  Machine Learning Infrastructure Engineer
# 19                               ML Engineer
# 20                              AI Scientist
# ...

# %% [markdown]
# <a id='question05'></a>
# ## Question 05

# %%
df_5 = df.groupby('job_title')[['salary_in_usd']].mean().rename(columns = {
                                      'salary_in_usd':'salary_in_usd (mean)'})
df_5
# Out:
#                                           salary_in_usd (mean)
# job_title
# 3D Computer Vision Researcher                      5409.000000
# AI Scientist                                      66135.571429
# Analytics Engineer                               175000.000000
# Applied Data Scientist                           175655.000000
# Applied Machine Learning Scientist               142068.750000
# BI Data Analyst                                   74755.166667
# Big Data Architect                                99703.000000
# Big Data Engineer                                 51974.000000
# Business Data Analyst                             76691.200000
# Cloud Data Engineer                              124647.000000
# Computer Vision Engineer                          44419.333333
# Computer Vision Software Engineer                105248.666667
# Data Analyst                                      92893.061856
# Data Analytics Engineer                           64799.250000
# ...

# %%
df_5.sort_values(by='salary_in_usd (mean)', ascending=False)
# Out:
#                                           salary_in_usd (mean)
# job_title
# Data Analytics Lead                              405000.000000
# Principal Data Engineer                          328333.333333
# Financial Data Analyst                           275000.000000
# Principal Data Scientist                         215242.428571
# Director of Data Science                         195074.000000
# Data Architect                                   177873.909091
# Applied Data Scientist                           175655.000000
# Analytics Engineer                               175000.000000
# Data Specialist                                  165000.000000
# Head of Data                                     160162.600000
# Machine Learning Scientist                       158412.500000
# Data Science Manager                             158328.500000
# Director of Data Engineering                     156738.000000
# Head of Data Science                             146718.750000
# ...

# %%
df.groupby('job_title')[['salary_in_usd']].mean().sort_values(by='salary_in_usd', ascending=False).head(1)
# Out:
#                      salary_in_usd
# job_title
# Data Analytics Lead       405000.0

# %%
# argmax(), idxmax(), max()
df.groupby('job_title')['salary_in_usd'].mean().idxmax()
# Out:
# 'Data Analytics Lead'

# %%
df.groupby('job_title')['salary_in_usd'].max()
# Out:
# job_title
# 3D Computer Vision Researcher                 5409
# AI Scientist                                200000
# Analytics Engineer                          205300
# Applied Data Scientist                      380000
# Applied Machine Learning Scientist          423000
# BI Data Analyst                             150000
# Big Data Architect                           99703
# Big Data Engineer                           114047
# Business Data Analyst                       135000
# Cloud Data Engineer                         160000
# Computer Vision Engineer                    125000
# Computer Vision Software Engineer           150000
# Data Analyst                                200000
# Data Analytics Engineer                     110000
# Data Analytics Lead                         405000
# Data Analytics Manager                      150260
# Data Architect                              266400
# Data Engineer                               324000
# ...

# %%
df.groupby('job_title')['salary_in_usd'].max().idxmax()
# Out:
# 'Principal Data Engineer'

# %%
df.iloc[df['salary_in_usd'].idxmax()]['job_title']
# Out:
# 'Principal Data Engineer'

# %%
df['salary_in_usd'].idxmax()
# Out:
# 252

# %% [markdown]
# <a id='question06'></a>
# ## Question 06

# %%
df_5.loc[['Machine Learning Engineer']]
# Out:
#                            salary_in_usd (mean)
# job_title
# Machine Learning Engineer         104880.146341

# %%
df['job_title']=='Machine Learning Engineer'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# Name: job_title, Length: 607, dtype: bool

# %%
df[df['job_title']=='Machine Learning Engineer']
# Out:
#      work_year experience_level employment_type                  job_title  \
# 4         2020               SE              FT  Machine Learning Engineer
# 20        2020               MI              FT  Machine Learning Engineer
# 37        2020               EN              FT  Machine Learning Engineer
# 39        2020               EN              FT  Machine Learning Engineer
# 64        2020               SE              FT  Machine Learning Engineer
# 83        2021               MI              FT  Machine Learning Engineer
# 110       2021               SE              FT  Machine Learning Engineer
# 128       2021               EN              FT  Machine Learning Engineer
# 145       2021               SE              FT  Machine Learning Engineer
# 159       2021               EN              FT  Machine Learning Engineer
# 178       2021               EN              FT  Machine Learning Engineer
# ...

# %%
df[df['job_title']=='Machine Learning Engineer']['salary_in_usd'].mean()
# Out:
# 104880.14634146342

# %%
df.groupby('job_title').mean().loc['Machine Learning Engineer']['salary_in_usd']
# Out:
# 104880.14634146342

# %% [markdown]
# <a id='question07'></a>
# ## Question 07
#
#
#
# <hr>
# work_year, experience_level, job_title, salary, company_size

# %%
df.sort_values(by='salary_in_usd')[['work_year', 'experience_level', 
                         'job_title', 'salary_in_usd', 'company_size']].head(10)
# Out:
#      work_year experience_level                      job_title  salary_in_usd  \
# 176       2021               MI                 Data Scientist           2859
# 185       2021               MI                  Data Engineer           4000
# 238       2021               EN                 Data Scientist           4000
# 77        2021               MI  3D Computer Vision Researcher           5409
# 179       2021               MI                 Data Scientist           5679
# 18        2020               EN        Data Science Consultant           5707
# 213       2021               EN              Big Data Engineer           5882
# 50        2020               EN                   Data Analyst           6072
# 21        2020               MI           Product Data Analyst           6072
# 15        2020               MI                   Data Analyst           8000
#
#     company_size
# 176            S
# 185            M
# 238            M
# 77             M
# 179            S
# ...

# %% [markdown]
# <a id='question08'></a>
# ## Question 08
#
#
#
# <hr>
# Use groupby
#
# job_title, count

# %%
df.groupby('job_title')[['work_year']].count()
# Out:
#                                           work_year
# job_title
# 3D Computer Vision Researcher                     1
# AI Scientist                                      7
# Analytics Engineer                                4
# Applied Data Scientist                            5
# Applied Machine Learning Scientist                4
# BI Data Analyst                                   6
# Big Data Architect                                1
# Big Data Engineer                                 8
# Business Data Analyst                             5
# Cloud Data Engineer                               2
# Computer Vision Engineer                          6
# Computer Vision Software Engineer                 3
# Data Analyst                                     97
# Data Analytics Engineer                           4
# Data Analytics Lead                               1
# Data Analytics Manager                            7
# Data Architect                                   11
# ...

# %%
df.groupby('job_title')[['work_year']].count().rename(columns = {'work_year':'Count'})
# Out:
#                                           Count
# job_title
# 3D Computer Vision Researcher                 1
# AI Scientist                                  7
# Analytics Engineer                            4
# Applied Data Scientist                        5
# Applied Machine Learning Scientist            4
# BI Data Analyst                               6
# Big Data Architect                            1
# Big Data Engineer                             8
# Business Data Analyst                         5
# Cloud Data Engineer                           2
# Computer Vision Engineer                      6
# Computer Vision Software Engineer             3
# Data Analyst                                 97
# Data Analytics Engineer                       4
# Data Analytics Lead                           1
# Data Analytics Manager                        7
# Data Architect                               11
# Data Engineer                               132
# ...

# %%
df.groupby('job_title').agg({"job_title":["count"]})
# Out:
#                                          job_title
#                                              count
# job_title
# 3D Computer Vision Researcher                    1
# AI Scientist                                     7
# Analytics Engineer                               4
# Applied Data Scientist                           5
# Applied Machine Learning Scientist               4
# BI Data Analyst                                  6
# Big Data Architect                               1
# Big Data Engineer                                8
# Business Data Analyst                            5
# Cloud Data Engineer                              2
# Computer Vision Engineer                         6
# Computer Vision Software Engineer                3
# Data Analyst                                    97
# Data Analytics Engineer                          4
# Data Analytics Lead                              1
# Data Analytics Manager                           7
# ...

# %%
df[['job_title']].value_counts()
# Out:
# job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Director of Data Science                      7
# AI Scientist                                  7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Data Analytics Manager                        7
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# ML Engineer                                   6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# ...

# %%
pd.DataFrame(df[['job_title']].value_counts(), columns=['Count'])
# Out:
#                                           Count
# job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Director of Data Science                      7
# AI Scientist                                  7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Data Analytics Manager                        7
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# ML Engineer                                   6
# Lead Data Engineer                            6
# ...

# %% [markdown]
# <a id='question09'></a>
# ## Question 09

# %%
df.groupby(['work_year'])[['salary_in_usd', 'job_title']].apply(lambda x: x.sort_values(
                                               by='salary_in_usd', ascending=False)[:3])
# Out:
#                salary_in_usd                           job_title
# work_year
# 2020      33          450000                  Research Scientist
#           63          412000                      Data Scientist
#           25          325000            Director of Data Science
# 2021      252         600000             Principal Data Engineer
#           97          450000              Financial Data Analyst
#           157         423000  Applied Machine Learning Scientist
# 2022      523         405000                 Data Analytics Lead
#           519         380000              Applied Data Scientist
#           482         324000                       Data Engineer

# %%
df.groupby(['work_year'])[['salary', 'job_title']].apply(lambda x: x.sort_values(
                                                                   by='salary', ascending=False).head(3))
# Out:
#                  salary                 job_title
# work_year
# 2020      7    11000000            Data Scientist
#           16    4450000             Data Engineer
#           11    3000000            Data Scientist
# 2021      177  30400000            Data Scientist
#           102  11000000           BI Data Analyst
#           137   8500000               ML Engineer
# 2022      384   6000000  Head of Machine Learning
#           459   2400000            Data Scientist
#           458   1400000     Business Data Analyst

# %%
work_year = df['work_year'].unique()
work_year
# Out:
# array([2020, 2021, 2022], dtype=int64)

# %%
df.groupby('work_year')[['job_title', 'salary_in_usd']].apply(lambda x: (x.groupby(
    'job_title')[['salary_in_usd']].mean()).sort_values(by='salary_in_usd', ascending=False)[:3])
# Out:
#                                       salary_in_usd
# work_year job_title
# 2020      Director of Data Science    325000.000000
#           Machine Learning Scientist  260000.000000
#           Research Scientist          246000.000000
# 2021      Financial Data Analyst      450000.000000
#           Principal Data Engineer     328333.333333
#           Principal Data Scientist    239152.400000
# 2022      Data Analytics Lead         405000.000000
#           Applied Data Scientist      238000.000000
#           Director of Data Science    196979.000000

# %%
df.groupby(['work_year', 'job_title'])[['salary_in_usd']].groups
# Out:
# {(2020, 'AI Scientist'): [52], (2020, 'BI Data Analyst'): [23], (2020, 'Big Data Engineer'): [2, 17, 31], (2020, 'Business Data Analyst'): [8, 28], (2020, 'Computer Vision Engineer'): [54], (2020, 'Data Analyst'): [5, 14, 15, 34, 38, 50, 51], (2020, 'Data Engineer'): [16, 22, 27, 35, 43, 44, 47, 49, 53, 60, 61], (2020, 'Data Engineering Manager'): [30, 41], (2020, 'Data Science Consultant'): [18, 36], (2020, 'Data Science Manager'): [67], (2020, 'Data Scientist'): [0, 7, 10, 11, 12, 32, 40, 46, 48, 56, 57, 58, 59, 62, 63, 65, 66, 68, 69, 70, 71], (2020, 'Director of Data Science'): [25], (2020, 'Lead Data Analyst'): [13], (2020, 'Lead Data Engineer'): [9, 19], (2020, 'Lead Data Scientist'): [6, 24], (2020, 'ML Engineer'): [45], (2020, 'Machine Learning Engineer'): [4, 20, 37, 39, 64], (2020, 'Machine Learning Infrastructure Engineer'): [42], (2020, 'Machine Learning Manager'): [29], (2020, 'Machine Learning Scientist'): [1], (2020, 'Principal Data Scientist'): [55], (2020, 'Product D
# ...

# %%
df.groupby(['work_year', 'job_title'], as_index=False)[['salary_in_usd']].mean()
# Out:
#     work_year                   job_title  salary_in_usd
# 0        2020                AI Scientist   45896.000000
# 1        2020             BI Data Analyst   98000.000000
# 2        2020           Big Data Engineer   97690.333333
# 3        2020       Business Data Analyst  117500.000000
# 4        2020    Computer Vision Engineer   60000.000000
# ..        ...                         ...            ...
# 93       2022  Machine Learning Scientist  141766.666667
# 94       2022                NLP Engineer   37236.000000
# 95       2022      Principal Data Analyst   75000.000000
# 96       2022    Principal Data Scientist  162674.000000
# 97       2022          Research Scientist  105569.000000
#
# [98 rows x 3 columns]

# %%
df.groupby(['work_year', 'job_title'], as_index=False)[['salary_in_usd']].mean().groupby(
    'work_year').apply(lambda x: x.sort_values(by='salary_in_usd', ascending=False)[:3])
# Out:
#               work_year                   job_title  salary_in_usd
# work_year
# 2020      11       2020    Director of Data Science  325000.000000
#           19       2020  Machine Learning Scientist  260000.000000
#           22       2020          Research Scientist  246000.000000
# 2021      48       2021      Financial Data Analyst  450000.000000
#           61       2021     Principal Data Engineer  328333.333333
#           62       2021    Principal Data Scientist  239152.400000
# 2022      74       2022         Data Analytics Lead  405000.000000
#           67       2022      Applied Data Scientist  238000.000000
#           81       2022    Director of Data Science  196979.000000

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h1 class="alert-heading">Well done!</h1>
#   <p>Best Wishes!, Filoger</p>
# </div>
