# %%
import numpy as np
# import random

# %%
print('Rock...'.lower())
print('Paper...'.lower())
print('Scissors...'.lower())
print('-------------------------')


randomNumber = np.random.randint(0, 3)

if randomNumber == 0:
    computerMove = 'rock'
elif randomNumber == 1:
    computerMove = 'paper'
elif randomNumber == 2:
    computerMove = 'scissors'
    
    
player_1 = input('player_1 , Make your move : ').lower()
print(f'player_2 , Make your move : {computerMove}')

player_2 = computerMove


if player_1 == player_2:
    print('thats a tie ...')
    
elif player_1 == 'rock':
    if player_2 == 'scissors':
        print('player_1 wins!...')
    elif player_2 == 'paper':
        print('player_2 wins!...')
        
elif player_1 == 'paper':
    if player_2 == 'rock':
        print('player_1 wins!...')
    elif player_2 == 'scissors':
        print('player_2 wins!...')
        
elif player_1 == 'scissors':
    if player_2 == 'paper':
        print('player_1 wins!...')
    elif player_2 == 'rock':
        print('player_2 wins!...')
# Out:
# rock...
# paper...
# scissors...
# -------------------------
# player_1 , Make your move : paper
# player_2 , Make your move : paper
# thats a tie ...

# %%
print('Rock...'.lower())
print('Paper...'.lower())
print('Scissors...'.lower())
print('-------------------------')


for time in range(0, 3):
    randomNumber = np.random.randint(0, 3)

    if randomNumber == 0:
        computerMove = 'rock'
    elif randomNumber == 1:
        computerMove = 'paper'
    elif randomNumber == 2:
        computerMove = 'scissors'


    player_1 = input('\nplayer_1 , Make your move : ').lower()
    print(f'player_2 , Make your move : {computerMove}')

    player_2 = computerMove


    if player_1 == player_2:
        print('thats a tie ...')

    elif player_1 == 'rock':
        if player_2 == 'scissors':
            print('player_1 wins!...')
        elif player_2 == 'paper':
            print('player_2 wins!...')

    elif player_1 == 'paper':
        if player_2 == 'rock':
            print('player_1 wins!...')
        elif player_2 == 'scissors':
            print('player_2 wins!...')

    elif player_1 == 'scissors':
        if player_2 == 'paper':
            print('player_1 wins!...')
        elif player_2 == 'rock':
            print('player_2 wins!...')
# Out:
# rock...
# paper...
# scissors...
# -------------------------
#
# player_1 , Make your move : paper
# player_2 , Make your move : paper
# thats a tie ...
#
# player_1 , Make your move : paper
# player_2 , Make your move : scissors
# player_2 wins!...
#
# player_1 , Make your move : scissors
# player_2 , Make your move : paper
# player_1 wins!...

# %%
print('Rock...'.lower())
print('Paper...'.lower())
print('Scissors...'.lower())
print('-------------------------')


player_1_wins = 0
player_2_wins = 0
winning_score = 3

while player_1_wins < winning_score and player_2_wins < winning_score:
    print(f'player_1 wins : {player_1_wins} and player_2 wins : {player_2_wins}')
    
    randomNumber = np.random.randint(0, 3)

    if randomNumber == 0:
        computerMove = 'rock'
    elif randomNumber == 1:
        computerMove = 'paper'
    elif randomNumber == 2:
        computerMove = 'scissors'


    player_1 = input('\nplayer_1 , Make your move : ').lower()
    print(f'player_2 , Make your move : {computerMove}')

    player_2 = computerMove
    
    
    if player_1 == 'q' or player_1 == 'quit':
        break


    if player_1 == player_2:
        print('thats a tie ...')

    elif player_1 == 'rock':
        if player_2 == 'scissors':
            print('player_1 wins!...')
            player_1_wins += 1
        elif player_2 == 'paper':
            print('player_2 wins!...')
            player_2_wins += 1

    elif player_1 == 'paper':
        if player_2 == 'rock':
            print('player_1 wins!...')
            player_1_wins += 1
        elif player_2 == 'scissors':
            print('player_2 wins!...')
            player_2_wins += 1

    elif player_1 == 'scissors':
        if player_2 == 'paper':
            print('player_1 wins!...')
            player_1_wins += 1
        elif player_2 == 'rock':
            print('player_2 wins!...')
            player_2_wins += 1
            
print(f'Final Scores: player_1 wins : {player_1_wins} | player_2 wins : {player_2_wins}')
# Out:
# rock...
# paper...
# scissors...
# -------------------------
# player_1 wins : 0 and player_2 wins : 0
#
# player_1 , Make your move : rock
# player_2 , Make your move : paper
# player_2 wins!...
# player_1 wins : 0 and player_2 wins : 1
#
# player_1 , Make your move : paper
# player_2 , Make your move : scissors
# player_2 wins!...
# player_1 wins : 0 and player_2 wins : 2
#
# player_1 , Make your move : rock
# player_2 , Make your move : rock
# thats a tie ...
# player_1 wins : 0 and player_2 wins : 2
#
# player_1 , Make your move : rock
# player_2 , Make your move : paper
# player_2 wins!...
# Final Scores: player_1 wins : 0 | player_2 wins : 3
